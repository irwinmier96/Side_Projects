# %%
import pandas as pd
import numpy as np

import bokeh
from bokeh.io import show
from bokeh.sampledata.les_mis import data

# %%
df = pd.read_csv("Datasets/2010s_Titles")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ID                              Title  Year  Age  \
# 0           0             0   1                          Inception  2010  13+
# 1           2             2   3             Avengers: Infinity War  2018  13+
# 2           5             5   6  Spider-Man: Into the Spider-Verse  2018   7+
# 3           7             7   8                   Django Unchained  2012  18+
# 4          13            13  14                               Room  2015  18+
#
#    IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0   8.8             87%        1     0            0        0     0
# 1   8.5             84%        1     0            0        0     0
# 2   8.4             97%        1     0            0        0     0
# 3   8.4             87%        1     0            0        0     0
# 4   8.1             93%        1     0            0        0     0
#
#                                      Directors  \
# ...

# %%
df.Directors.unique()
# Out:
# array(['Christopher Nolan', 'Anthony Russo,Joe Russo',
#        'Bob Persichetti,Peter Ramsey,Rodney Rothman', ...,
#        'Michael Lembeck', 'Joe Nussbaum', 'Steven K. Tsuchida'],
#       dtype=object)

# %%
df.Genres.unique()
# Out:
# array(['Action,Adventure,Sci-Fi,Thriller', 'Action,Adventure,Sci-Fi',
#        'Animation,Action,Adventure,Family,Sci-Fi', 'Drama,Western',
#        'Drama,Thriller', 'Biography,Drama,History',
#        'Drama,Romance,Sci-Fi', 'Biography,Drama', 'Drama,Romance',
#        'Drama,Mystery,Sci-Fi,Thriller', 'Comedy,Drama,Romance',
#        'Biography,Crime,Drama', 'Crime,Drama',
#        'Animation,Action,Adventure,Comedy,Family,Sci-Fi',
#        'Action,Biography,Drama,Sport',
#        'Animation,Adventure,Comedy,Family',
#        'Animation,Comedy,Family,Fantasy',
#        'Action,Crime,Drama,Thriller,Western', 'Biography,Drama,Romance',
#        'Documentary,Biography,Sport', 'Action,Comedy,Fantasy,Romance',
#        'Crime,Drama,Mystery,Thriller,Western', 'Drama',
#        'Drama,Family,Fantasy,Mystery', 'Action,Adventure,Comedy,Sci-Fi',
#        'Documentary,Biography,Music', 'Documentary,News',
#        'Action,Crime,Drama', 'Crime,Mystery,Thriller',
# ...

# %%
#Find pairings??? by genre 

#Bokeh Chord Diagram connecting the genres

##https://pypi.org/project/chord/
