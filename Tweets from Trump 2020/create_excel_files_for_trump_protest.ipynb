# %%
import tweepy
import datetime
import xlsxwriter
import sys
import config

# %%
#Connect to Twitter

##Possible ref: 
##https://blog.f-secure.com/how-to-get-tweets-from-a-twitter-account-using-python-and-tweepy/
consumerKey = config.api_key
consumerSecret = config.api_secret
accessToken = config.access_token
accessTokenSecret = config.access_token_secret

# %%
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)

# %%
api = tweepy.API(auth)

# %%
## Attribute Error issue:
## Solution: https://stackoverflow.com/questions/12906402/type-object-datetime-datetime-has-no-attribute-datetime
username = "realDonaldTrump"
startDate = datetime.datetime(2020, 5, 25, 0, 0, 0)
endDate =   datetime.datetime(2020, 6, 8, 0, 0, 0)

# %%
tweets = []
tmpTweets = api.user_timeline(username, count = 40)
for tweet in tmpTweets:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        tweets.append(tweet)

# %%
tmpTweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001EFAAB53CF8>, _json={'created_at': 'Mon Jun 08 19:15:35 +0000 2020', 'id': 1270071995363987461, 'id_str': '1270071995363987461', 'text': 'https://t.co/wZc0PgCmnJ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/wZc0PgCmnJ', 'expanded_url': 'https://dailycaller.com/2020/06/08/george-w-bush-spokesman-new-york-times-article-donald-trump/', 'display_url': 'dailycaller.com/2020/06/08/geo…', 'indices': [0, 23]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 25073877, 'id_str': '25073877', 'name': 'Donald J. Trump', 'screen_name': 'realDonaldTrump', 'location': 'Washington, DC', 'description': '45th President of the United States of America🇺🇸', 'url': 'h
# ...

# %%
while (tmpTweets[-1].created_at > startDate):
    tmpTweets = api.user_timeline(username, max_id = tmpTweets[-1].id)
    for tweet in tmpTweets:
        if tweet.created_at < endDate and tweet.created_at > startDate:
            tweets.append(tweet)

# %%
tweet
# Out:
# Status(_api=<tweepy.api.API object at 0x000001EFAAB53CF8>, _json={'created_at': 'Sun May 24 13:30:00 +0000 2020', 'id': 1264549210218790912, 'id_str': '1264549210218790912', 'text': '“Full Measure with Sheryl Attkisson” interview on @ABC at 10:00 A.M. Sunday. Enjoy!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ABC', 'name': 'ABC News', 'id': 28785486, 'id_str': '28785486', 'indices': [50, 54]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 25073877, 'id_str': '25073877', 'name': 'Donald J. Trump', 'screen_name': 'realDonaldTrump', 'location': 'Washington, DC', 'description': '45th President of the United States of America🇺🇸', 'url': 'https://t.co/OMxB0x7xC5', 'entities': {'url': {'urls': [{'ur
# ...

# %%
workbook = xlsxwriter.Workbook(username + "sincemayprotest.xlsx")
worksheet = workbook.add_worksheet()
row = 0
for tweet in tweets:
    worksheet.write_string(row, 0, str(tweet.id))
    worksheet.write_string(row, 1, str(tweet.created_at))
    worksheet.write(row, 2, tweet.text)
    row += 1

workbook.close()
print("Excel file ready")
# Out:
# Excel file ready

# %%
##Reference Code: https://gist.github.com/alexdeloy/fdb36ad251f70855d5d6
##Had to tweak the code since the original had errors, and didnt want the fourth row in my Excel file
