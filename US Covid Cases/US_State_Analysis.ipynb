# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Datasets/us-states.csv")
df = pd.DataFrame(df)
df = df.drop(columns = 'Unnamed: 0')

df
# Out:
#                        state  2020-01-21 00:00:00  2020-01-22 00:00:00  \
# 0                    Alabama                    0                    0
# 1                     Alaska                    0                    0
# 2                    Arizona                    0                    0
# 3                   Arkansas                    0                    0
# 4                 California                    0                    0
# 5                   Colorado                    0                    0
# 6                Connecticut                    0                    0
# 7                   Delaware                    0                    0
# 8       District of Columbia                    0                    0
# 9                    Florida                    0                    0
# 10                   Georgia                    0                    0
# 11                      Guam                    0                    0
# ...

# %%
df = df.set_index('state')
df
# Out:
#                           2020-01-21 00:00:00  2020-01-22 00:00:00  \
# state
# Alabama                                     0                    0
# Alaska                                      0                    0
# Arizona                                     0                    0
# Arkansas                                    0                    0
# California                                  0                    0
# Colorado                                    0                    0
# Connecticut                                 0                    0
# Delaware                                    0                    0
# District of Columbia                        0                    0
# Florida                                     0                    0
# Georgia                                     0                    0
# Guam                                        0                    0
# Hawaii                                      0                    0
# ...

# %%
States_to_plot = ['New York', 'New Jersey', 'California', 'Illinois', 'Florida', 'Texas', 'Massachusetts']
plt.plot(df['state'])
