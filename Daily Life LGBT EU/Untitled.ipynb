# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
lgbt = pd.read_csv("Datasets/LGBT_Survey_DailyLife.csv")
lgbt = pd.DataFrame(lgbt)

lgbt.head()
# Out:
#   CountryCode   subset question_code  \
# 0     Austria  Lesbian          b1_a
# 1     Austria  Lesbian          b1_a
# 2     Austria  Lesbian          b1_a
# 3     Austria  Lesbian          b1_a
# 4     Austria  Lesbian          b1_a
#
#                                       question_label             answer  \
# 0  In your opinion, how widespread is offensive l...    Very widespread
# 1  In your opinion, how widespread is offensive l...  Fairly widespread
# 2  In your opinion, how widespread is offensive l...        Fairly rare
# 3  In your opinion, how widespread is offensive l...          Very rare
# 4  In your opinion, how widespread is offensive l...         Don`t know
#
#   percentage notes
# 0          8   NaN
# 1         34   NaN
# 2         45   NaN
# 3          9   NaN
# 4          4   [0]

# %%
lgbt["question_label"].unique()
# Out:
# array(['In your opinion, how widespread is offensive language about lesbian, gay, bisexual and/or transgender people by politicians in the country where you live?',
#        'In your opinion, how widespread are casual jokes in everyday life about lesbian, gay, bisexual and/or transgender people in the country you live?',
#        'In your opinion, how widespread are expressions of hatred and aversion towards lesbian, gay, bisexual and/or transgender in public in the country where you live?',
#        'In your opinion, how widespread are assaults and harassment against lesbian, gay, bisexual and/or transgender people in the country where you live?',
#        'In your opinion, how widespread is same-sex partners holding hands in public in the country where you live?',
#        'In your opinion, how widespread is heterosexual partners holding hands in public in the country where you live?',
# ...

# %%
lgbt.dtypes
# Out:
# CountryCode       object
# subset            object
# question_code     object
# question_label    object
# answer            object
# percentage        object
# notes             object
# dtype: object

# %%
lgbt['CountryCode'].unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Cyprus', 'Czech Republic',
#        'Germany', 'Denmark', 'Estonia', 'Greece', 'Spain', 'Finland',
#        'France', 'Croatia', 'Hungary', 'Ireland', 'Italy', 'Lithuania',
#        'Luxembourg', 'Latvia', 'Malta', 'Netherlands', 'Poland',
#        'Portugal', 'Romania', 'Sweden', 'Slovenia', 'Slovakia',
#        'United Kingdom', 'Average'], dtype=object)

# %%
#create stacked bar charts by question and subset
b1_a_df = lgbt[lgbt['question_code'] == 'b1_a']
b1_a_df = pd.DataFrame(b1_a_df)

b1_a_df
# Out:
#         CountryCode          subset question_code  \
# 0           Austria         Lesbian          b1_a
# 1           Austria         Lesbian          b1_a
# 2           Austria         Lesbian          b1_a
# 3           Austria         Lesbian          b1_a
# 4           Austria         Lesbian          b1_a
# 5           Austria             Gay          b1_a
# 6           Austria             Gay          b1_a
# 7           Austria             Gay          b1_a
# 8           Austria             Gay          b1_a
# 9           Austria             Gay          b1_a
# 10          Austria  Bisexual women          b1_a
# 11          Austria  Bisexual women          b1_a
# 12          Austria  Bisexual women          b1_a
# 13          Austria  Bisexual women          b1_a
# 14          Austria  Bisexual women          b1_a
# 15          Austria    Bisexual men          b1_a
# 16          Austria    Bisexual men          b1_a
# 17          Austria    Bisexual men          b1_a
# ...

# %%
# del b1_a_df["question_label"]
# del b1_a_df["notes"]
b1_a_df
# Out:
#         CountryCode          subset             answer percentage
# 0           Austria         Lesbian    Very widespread          8
# 1           Austria         Lesbian  Fairly widespread         34
# 2           Austria         Lesbian        Fairly rare         45
# 3           Austria         Lesbian          Very rare          9
# 4           Austria         Lesbian         Don`t know          4
# 5           Austria             Gay    Very widespread          4
# 6           Austria             Gay  Fairly widespread         21
# 7           Austria             Gay        Fairly rare         52
# 8           Austria             Gay          Very rare         20
# 9           Austria             Gay         Don`t know          4
# 10          Austria  Bisexual women    Very widespread          9
# 11          Austria  Bisexual women  Fairly widespread         29
# 12          Austria  Bisexual women        Fairly rare         48
# ...

# %%
#Compare answers in just Austria and then attempt other nations
b1_Austria_df = b1_a_df[b1_a_df["CountryCode"] == "Austria"]
b1_Austria_df = pd.DataFrame(b1_Austria_df)

b1_Austria_df["percentage"] = b1_Austria_df["percentage"].astype(str).astype(int)

b1_Austria_df
# Out:
#    CountryCode          subset             answer  percentage
# 0      Austria         Lesbian    Very widespread           8
# 1      Austria         Lesbian  Fairly widespread          34
# 2      Austria         Lesbian        Fairly rare          45
# 3      Austria         Lesbian          Very rare           9
# 4      Austria         Lesbian         Don`t know           4
# 5      Austria             Gay    Very widespread           4
# 6      Austria             Gay  Fairly widespread          21
# 7      Austria             Gay        Fairly rare          52
# 8      Austria             Gay          Very rare          20
# 9      Austria             Gay         Don`t know           4
# 10     Austria  Bisexual women    Very widespread           9
# 11     Austria  Bisexual women  Fairly widespread          29
# 12     Austria  Bisexual women        Fairly rare          48
# 13     Austria  Bisexual women          Very rare           9
# ...

# %%
fig, ax = plt.subplots(figsize=(25,18))  

answers = b1_Austria_df['answer'].drop_duplicates()
margin_bottom = np.zeros(len(b1_Austria_df['subset'].drop_duplicates()))
colors = ["orangered", "gold","aquamarine", "darkviolet", "palevioletred"]

for col, answer in enumerate(answers):
    values = list(b1_Austria_df[b1_Austria_df['answer'] == answer].loc[:, 'percentage'])

    b1_Austria_df[b1_Austria_df['answer'] == answer].plot.bar(x='subset',y='percentage', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[col], label=answer)
    margin_bottom += values
    
    plt.grid()
    
    plt.xticks(rotation=45, fontsize = 20)
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.xlabel("Subsets for Austria", fontsize = 20)

    plt.ylabel("Percentage", fontsize = 20)
    
plt.title("Austria LGBT: In your opinion, how widespread is offensive language about lesbian, gay, bisexual and/or transgender people by politicians in the country where you live?", fontsize = 25)

plt.savefig("Visualizations/Austria_Question_b1_a_by_s")

plt.show()

# %%
#Next barchart will focus on a certain question but will go by country with different subsets

lgbt_question = lgbt[lgbt['question_label'] == 'In your opinion, how widespread is public figures in politics, business, sports, etc being open about themselves being lesbian, gay, bisexual and/or transgender in the country where you live?']

lgbt_question = pd.DataFrame(lgbt_question)
lgbt_question.head()
# Out:
#      CountryCode   subset question_code  \
# 4350     Austria  Lesbian          b1_g
# 4351     Austria  Lesbian          b1_g
# 4352     Austria  Lesbian          b1_g
# 4353     Austria  Lesbian          b1_g
# 4354     Austria  Lesbian          b1_g
#
#                                          question_label             answer  \
# 4350  In your opinion, how widespread is public figu...    Very widespread
# 4351  In your opinion, how widespread is public figu...  Fairly widespread
# 4352  In your opinion, how widespread is public figu...        Fairly rare
# 4353  In your opinion, how widespread is public figu...          Very rare
# 4354  In your opinion, how widespread is public figu...         Don`t know
#
#      percentage notes
# 4350          1   [0]
# 4351         10   NaN
# 4352         57   NaN
# 4353         29   NaN
# 4354          3   [0]

# %%
b1_g_gay = lgbt_question[lgbt_question["subset"] == 'Gay']
b1_g_lesbian = lgbt_question[lgbt_question["subset"] == 'Lesbian']
b1_g_bi_men = lgbt_question[lgbt_question["subset"] == 'Bisexual men']
b1_g_bi_women = lgbt_question[lgbt_question["subset"] == 'Bisexual women']
b1_g_trans = lgbt_question[lgbt_question["subset"] == 'Transgender']


b1_g_gay = pd.DataFrame(b1_g_gay)
b1_g_lesbian = pd.DataFrame(b1_g_lesbian)
b1_g_bi_men = pd.DataFrame(b1_g_bi_men)
b1_g_bi_women = pd.DataFrame(b1_g_bi_women)
b1_g_trans = pd.DataFrame(b1_g_trans)

## Bisexual men, bisexual women, and transgender people have a : instead of a number, replace that with 0
b1_g_bi_men = b1_g_bi_men.replace(to_replace=':', value=0, regex=True)
b1_g_bi_women = b1_g_bi_women.replace(to_replace=':', value=0, regex=True)
b1_g_trans = b1_g_trans.replace(to_replace=':', value=0, regex=True)

b1_g_gay.percentage=pd.to_numeric(b1_g_gay.percentage)
b1_g_lesbian.percentage=pd.to_numeric(b1_g_lesbian.percentage)
b1_g_bi_men.percentage=pd.to_numeric(b1_g_bi_men.percentage)
b1_g_bi_women.percentage=pd.to_numeric(b1_g_bi_women.percentage)
b1_g_trans.percentage=pd.to_numeric(b1_g_trans.percentage)

fig, ax = plt.subplots(figsize=(20,10))  

answers = b1_g_gay['answer'].drop_duplicates()
margin_bottom = np.zeros(len(b1_g_gay['CountryCode'].drop_duplicates()))
colors = ["orangered", "gold","aquamarine", "darkviolet", "palevioletred"]

for col, answer in enumerate(answers):
    values = list(b1_g_gay[b1_g_gay['answer'] == answer].loc[:, 'percentage'])

    b1_g_gay[b1_g_gay['answer'] == answer].plot.bar(x='CountryCode',y='percentage', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[col], label=answer)
    margin_bottom += values
    
    plt.grid()
    
    plt.xticks(rotation=75, fontsize = 20)
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.xlabel("Countries in the EU", fontsize = 20)

    plt.ylabel("Percentage", fontsize = 20)
    
    plt.title("Gay: How widespread are public figures open about being LGBT in the country you live? ", fontsize = 25)

plt.savefig("Visualizations/Question_b1_g_Gay")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))  

answers = b1_g_lesbian['answer'].drop_duplicates()
margin_bottom = np.zeros(len(b1_g_lesbian['CountryCode'].drop_duplicates()))
colors = ["orangered", "gold","aquamarine", "darkviolet", "palevioletred"]

for col, answer in enumerate(answers):
    values = list(b1_g_lesbian[b1_g_lesbian['answer'] == answer].loc[:, 'percentage'])

    b1_g_lesbian[b1_g_lesbian['answer'] == answer].plot.bar(x='CountryCode',y='percentage', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[col], label=answer)
    margin_bottom += values
    
    plt.grid()
    
    plt.xticks(rotation=75, fontsize = 20)
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.xlabel("Countries in the EU", fontsize = 20)

    plt.ylabel("Percentage", fontsize = 20)
    
    plt.title("Lesbian: How widespread are public figures open about being LGBT in the country you live? ", fontsize = 25)

plt.savefig("Visualizations/Question_b1_g_Lesbian")

plt.show()

# %%
b1_g_bi_men.replace(to_replace=':', value=0, regex=True)
# Out:
#          CountryCode        subset question_code  \
# 4365         Austria  Bisexual men          b1_g
# 4366         Austria  Bisexual men          b1_g
# 4367         Austria  Bisexual men          b1_g
# 4368         Austria  Bisexual men          b1_g
# 4369         Austria  Bisexual men          b1_g
# 4390         Belgium  Bisexual men          b1_g
# 4391         Belgium  Bisexual men          b1_g
# 4392         Belgium  Bisexual men          b1_g
# 4393         Belgium  Bisexual men          b1_g
# 4394         Belgium  Bisexual men          b1_g
# 4415        Bulgaria  Bisexual men          b1_g
# 4416        Bulgaria  Bisexual men          b1_g
# 4417        Bulgaria  Bisexual men          b1_g
# 4418        Bulgaria  Bisexual men          b1_g
# 4419        Bulgaria  Bisexual men          b1_g
# 4440          Cyprus  Bisexual men          b1_g
# 4441          Cyprus  Bisexual men          b1_g
# 4442          Cyprus  Bisexual men          b1_g
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))  

answers = b1_g_bi_men['answer'].drop_duplicates()
margin_bottom = np.zeros(len(b1_g_bi_men['CountryCode'].drop_duplicates()))
colors = ["orangered", "gold","aquamarine", "darkviolet", "palevioletred"]

for col, answer in enumerate(answers):
    values = list(b1_g_bi_men[b1_g_bi_men['answer'] == answer].loc[:, 'percentage'])

    b1_g_bi_men[b1_g_bi_men['answer'] == answer].plot.bar(x='CountryCode',y='percentage', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[col], label=answer)
    margin_bottom += values
    
    plt.grid()
    
    plt.xticks(rotation=75, fontsize = 20)
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.xlabel("Countries in the EU", fontsize = 20)

    plt.ylabel("Percentage", fontsize = 20)
    
    plt.title("Bisexual Men: How widespread are public figures open about being LGBT in the country you live? ", fontsize = 25)

plt.savefig("Visualizations/Question_b1_g_Bisexual_Men")

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))  

answers = b1_g_bi_women['answer'].drop_duplicates()
margin_bottom = np.zeros(len(b1_g_bi_women['CountryCode'].drop_duplicates()))
colors = ["orangered", "gold","aquamarine", "darkviolet", "palevioletred"]

for col, answer in enumerate(answers):
    values = list(b1_g_bi_women[b1_g_bi_women['answer'] == answer].loc[:, 'percentage'])

    b1_g_bi_women[b1_g_bi_women['answer'] == answer].plot.bar(x='CountryCode',y='percentage', ax=ax, stacked=True, 
                                    bottom = margin_bottom, color=colors[col], label=answer)
    margin_bottom += values
    
    plt.grid()
    
    plt.xticks(rotation=75, fontsize = 20)
    
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    
    plt.xlabel("Countries in the EU", fontsize = 20)

    plt.ylabel("Percentage", fontsize = 20)
    
    plt.title("Bisexual Women: How widespread are public figures open about being LGBT in the country you live? ", fontsize = 25)

plt.savefig("Visualizations/Question_b1_g_Bisexual_Women")

plt.show()
